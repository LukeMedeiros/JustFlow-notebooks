# %%
import sys
from pymongo import MongoClient
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
db_password = "capstone123!"
with MongoClient("mongodb+srv://JustFlowAdmin:"+db_password+"@justflow-l8dim.mongodb.net/JustFlow?retryWrites=true&w=majority") as client:
    db = client.get_database('JustFlow')
    tracks_db = db.test_tracks_genre_focus
    tracks = list(tracks_db.find({}))

# %%
# genres = ['classical']

# for i in range(len(tracks)):
#     if(len(tracks[i]['genres'])!=0):
#         for genre in tracks[i]['genres']:
#             for g in genres:
#                 x = re.search(g, genre)
#                 if(x != None):
#                     tracks_db.update_one({'_id': tracks[i]['_id']}, {"$set": {'genres': [g]}})
#                     break

# %% [markdown]
# # Filtering by Tempo, Then performing KNN w/ MFCC + Chroma

# %%
for i in range(0, len(tracks), 10): 
    weights = {} 
    genre = tracks[i]['genres'][len(tracks[i]['genres'])-1]
#     for genre in genres: 
    if genre not in weights: 
        weights[genre] = 1
    else: 
        weights[genre] += 1
    count = 0 
    for key, value in tracks[i]['combined_neighbors'].items():
        compare = tracks_db.find_one({'_id' : key})
        compare_genre = compare['genres'][len(compare['genres'])-1]
        if np.sum(genre == compare_genre) > 0:
            count = count + 1
#         for genre in compare_genres: 
        if compare_genre not in weights:
            weights[compare_genre] = 1
        else: 
            weights[compare_genre] += 1
    plt.pie(weights.values(), labels=weights.keys(), autopct=None)
    plt.show()
    print('name: ', tracks[i]['name'])
    print('seed genre: ', genre)
    print(weights)
    print(count/len(tracks[i]['combined_neighbors']))
# Out:
# name:  Handel / Orch. Hale: Keyboard Suite in D Minor, HWV 437: III. Sarabande
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  8 Humoresques, Op. 101, B. 187: No. 7, Poco lento e grazioso (Transcribed by Oscar Morawetz for Violin, Cello & Orchestra)
# seed genre:  classical
# {'classical': 20, 'hip hop': 1}
# 0.95
# name:  Elgar: Variations on an Original Theme, Op. 36, Enigma: IX. Nimrod (Adagio)
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  Kinderszenen, Op. 15: No. 7 in F Major, Träumerei
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  Weint nicht um meinen Tod
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  Pergolesi: Stabat Mater: I. Stabat Mater dolorosa
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  Scent of a Woman: Tango (Por Una Cabeza)
# seed genre:  classical
# {'classical': 21}
# 1.0
# name:  All Night (feat. Ally Brooke)
# seed genre:  edm
# {'edm': 12, 'pop': 9}
# 0.55
# name:  Symphony
# seed genre:  edm
# {'edm': 16, 'pop': 5}
# 0.75
# name:  You're Not Alone
# seed genre:  edm
# {'edm': 16, 'pop': 5}
# 0.75
# name:  Maldad (with Maluma)
# seed genre:  edm
# {'edm': 7, 'hip hop': 5, 'pop': 9}
# 0.3
# name:  All The Love You Got
# seed genre:  edm
# {'edm': 10, 'pop': 8, 'hip hop': 3}
# 0.45
# name:  Next Level
# seed genre:  edm
# {'edm': 16, 'hip hop': 1, 'pop': 4}
# 0.75
# name:  Could Be You (feat. Danny Dearden)
# seed genre:  edm
# {'edm': 12, 'pop': 8, 'hip hop': 1}
# 0.55
# name:  Wild Wild West
# seed genre:  hip hop
# {'hip hop': 17, 'classical': 3, 'edm': 1}
# 0.8
# name:  It's Yours (Radio Mix)
# seed genre:  hip hop
# {'hip hop': 15, 'classical': 5, 'edm': 1}
# 0.7
# name:  Use Me
# seed genre:  hip hop
# {'hip hop': 16, 'classical': 5}
# 0.75
# name:  Call Me D-Nice
# seed genre:  hip hop
# {'hip hop': 14, 'classical': 4, 'pop': 1, 'edm': 2}
# 0.65
# name:  Break Dance - Electric Boogie
# seed genre:  hip hop
# {'hip hop': 19, 'classical': 2}
# 0.9
# name:  Change The Beat - French & English Rap
# seed genre:  hip hop
# {'hip hop': 17, 'pop': 1, 'edm': 1, 'classical': 2}
# 0.8
# name:  The Roof Is On Fire (Re-Recorded / Remastered)
# seed genre:  hip hop
# {'hip hop': 17, 'classical': 3, 'edm': 1}
# 0.8
# name:  Don't Start Now
# seed genre:  pop
# {'pop': 9, 'edm': 7, 'hip hop': 5}
# 0.4
# name:  Like I'm Gonna Lose You (feat. John Legend)
# seed genre:  pop
# {'pop': 9, 'edm': 5, 'hip hop': 6, 'classical': 1}
# 0.4
# name:  One Touch
# seed genre:  pop
# {'pop': 9, 'edm': 10, 'hip hop': 2}
# 0.4
# name:  stupid
# seed genre:  pop
# {'pop': 10, 'hip hop': 5, 'edm': 6}
# 0.45
# name:  Too Little Too Late - 2018
# seed genre:  pop
# {'pop': 8, 'edm': 12, 'hip hop': 1}
# 0.35
# name:  A Thousand Years
# seed genre:  pop
# {'pop': 13, 'edm': 6, 'hip hop': 2}
# 0.6

# %% [markdown]
# # Performing KNN only using MFCC

# %%
for i in range(0, len(tracks), 10): 
    weights = {} 
    genre = tracks[i]['genres'][len(tracks[i]['genres'])-1]
#     for genre in genres: 
    if genre not in weights: 
        weights[genre] = 1
    else: 
        weights[genre] += 1
    count = 0 
    for key, value in tracks[i]['mfcc_neighbors'].items():
        compare = tracks_db.find_one({'_id' : key})
        compare_genre = compare['genres'][len(compare['genres'])-1]
        if np.sum(genre == compare_genre) > 0:
            count = count + 1
#         for genre in compare_genres: 
        if compare_genre not in weights:
            weights[compare_genre] = 1
        else: 
            weights[compare_genre] += 1
    plt.pie(weights.values(), labels=weights.keys(), autopct=None)
    plt.show()
    print('name: ', tracks[i]['name'])
    print('seed genre: ', genre)
    print(weights)
    print(count/len(tracks[i]['mfcc_neighbors']))
